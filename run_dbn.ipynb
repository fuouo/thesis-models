# %%
import numpy as np
import pandas as pd

np.random.seed(1337)  # for reproducibility
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.regression import r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from dbn.tensorflow import SupervisedDBNRegression

# %%
#Preparing Dataset
# Read the dataset
ROAD = "Taft Ave."
YEAR = "2015"
EXT = ".csv"
DATE = "03-20-2015"
PRED = "715AM"
FILENAME = "test_" + ROAD + "_" + YEAR + "_" + DATE + "_" + "Pred-" + PRED

TIMESTEP = 10

original_dataset = pd.read_csv("data/testing/" + FILENAME + EXT, skipinitialspace=True)

# %%
original_dataset
# Out:
#                  dt lineName stationName  statusN  statusS   tempC     tempF  \
# 0   20/01/2015 3:30     EDSA   Taft Ave.      0.0      0.5  0.1500  0.180556
# 1   20/01/2015 3:45     EDSA   Taft Ave.      0.0      0.5  0.1500  0.187500
# 2   20/01/2015 4:00     EDSA   Taft Ave.      0.0      0.5  0.1500  0.194444
# 3   20/01/2015 4:15     EDSA   Taft Ave.      0.0      0.5  0.1625  0.194444
# 4   20/01/2015 4:30     EDSA   Taft Ave.      0.0      0.5  0.1750  0.194444
# 5   20/01/2015 4:45     EDSA   Taft Ave.      0.0      0.5  0.1875  0.194444
# 6   20/01/2015 5:00     EDSA   Taft Ave.      0.0      0.5  0.2000  0.194444
# 7   20/01/2015 5:15     EDSA   Taft Ave.      0.0      0.5  0.2000  0.201389
# 8   20/01/2015 5:30     EDSA   Taft Ave.      0.0      0.5  0.2000  0.208333
# 9   20/01/2015 5:45     EDSA   Taft Ave.      0.0      0.5  0.2000  0.215278
# 10  20/01/2015 6:00     EDSA   Taft Ave.      0.0      0.5  0.2000  0.222222
# 11  20/01/2015 6:15     EDSA   Taft Ave.      0.0      0.5  0.2250  0.243056
# 12  20/01/2015 6:30     EDSA   Taft Ave.      0.0      0.5  0.2500  0.263889
# 13  20/01/2015 6:45     EDSA   Taft Ave.      0.0      0.5  0.2750  0.284722
# 14  20/01/2015 7:00     EDSA   Taft Ave.      0.0      0.5  0.3000  0.305556
# 15  20/01/2015 7:15     EDSA   Taft Ave.      0.0      0.5  0.3125  0.326389
# 16  20/01/2015 7:30     EDSA   Taft Ave.      0.0      0.5  0.3250  0.347222
# 17  20/01/2015 7:45     EDSA   Taft Ave.      0.5      1.0  0.3375  0.368056
# 18  20/01/2015 8:00     EDSA   Taft Ave.      0.5      1.0  0.3500  0.388889
# 19  20/01/2015 8:15     EDSA   Taft Ave.      0.5      1.0  0.3750  0.409722
# 20  20/01/2015 8:30     EDSA   Taft Ave.      0.5      1.0  0.4000  0.430556
#
#     windspeedMiles  windspeedKmph  winddirDegree     ...      heatIndexC  \
# 0         0.125000       0.102273       0.274788     ...        0.189655
# 1         0.116071       0.096591       0.270538     ...        0.198276
# 2         0.107143       0.090909       0.266289     ...        0.206897
# 3         0.107143       0.090909       0.262040     ...        0.206897
# 4         0.107143       0.090909       0.257790     ...        0.206897
# 5         0.107143       0.090909       0.253541     ...        0.206897
# 6         0.107143       0.090909       0.249292     ...        0.206897
# 7         0.107143       0.085227       0.245042     ...        0.206897
# 8         0.107143       0.079545       0.240793     ...        0.206897
# 9         0.107143       0.073864       0.236544     ...        0.206897
# 10        0.107143       0.068182       0.232295     ...        0.206897
# 11        0.107143       0.068182       0.228754     ...        0.232759
# 12        0.107143       0.068182       0.225212     ...        0.258621
# 13        0.107143       0.068182       0.221671     ...        0.284483
# 14        0.107143       0.068182       0.218130     ...        0.310345
# 15        0.098214       0.068182       0.215297     ...        0.327586
# 16        0.089286       0.068182       0.212465     ...        0.344828
# 17        0.080357       0.068182       0.209632     ...        0.362069
# 18        0.071429       0.068182       0.206799     ...        0.379310
# 19        0.071429       0.068182       0.203258     ...        0.396552
# 20        0.071429       0.068182       0.199717     ...        0.413793
#
#     heatIndexF  dewPointC  dewPointF  windChillC  windChillF  windGustMiles  \
# 0     0.198113   0.461538       0.48      0.1500    0.180556       0.102273
# 1     0.202830   0.461538       0.48      0.1500    0.187500       0.096591
# 2     0.207547   0.461538       0.48      0.1500    0.194444       0.090909
# 3     0.212264   0.461538       0.48      0.1625    0.194444       0.090909
# 4     0.216981   0.461538       0.48      0.1750    0.194444       0.090909
# 5     0.221698   0.461538       0.48      0.1875    0.194444       0.090909
# 6     0.226415   0.461538       0.48      0.2000    0.194444       0.090909
# 7     0.226415   0.461538       0.48      0.2000    0.201389       0.085227
# 8     0.226415   0.461538       0.48      0.2000    0.208333       0.079545
# 9     0.226415   0.461538       0.48      0.2000    0.215278       0.073864
# 10    0.226415   0.461538       0.48      0.2000    0.222222       0.068182
# 11    0.245283   0.461538       0.49      0.2250    0.243056       0.068182
# 12    0.264151   0.461538       0.50      0.2500    0.263889       0.068182
# 13    0.283019   0.461538       0.51      0.2750    0.284722       0.068182
# 14    0.301887   0.461538       0.52      0.3000    0.305556       0.068182
# 15    0.320755   0.480769       0.52      0.3125    0.326389       0.062500
# 16    0.339623   0.500000       0.52      0.3250    0.347222       0.056818
# 17    0.358491   0.519231       0.52      0.3375    0.368056       0.051136
# 18    0.377358   0.538462       0.52      0.3500    0.388889       0.045455
# 19    0.396226   0.538462       0.53      0.3750    0.409722       0.039773
# 20    0.415094   0.538462       0.54      0.4000    0.430556       0.034091
#
#     windGustKmph  feelsLikeC  feelsLikeF
# 0       0.104167    0.189655    0.198113
# 1       0.100694    0.198276    0.202830
# 2       0.097222    0.206897    0.207547
# 3       0.093750    0.206897    0.212264
# 4       0.090278    0.206897    0.216981
# 5       0.086806    0.206897    0.221698
# 6       0.083333    0.206897    0.226415
# 7       0.079861    0.206897    0.226415
# 8       0.076389    0.206897    0.226415
# 9       0.072917    0.206897    0.226415
# 10      0.069444    0.206897    0.226415
# 11      0.069444    0.232759    0.245283
# 12      0.069444    0.258621    0.264151
# 13      0.069444    0.284483    0.283019
# 14      0.069444    0.310345    0.301887
# 15      0.065972    0.327586    0.320755
# 16      0.062500    0.344828    0.339623
# 17      0.059028    0.362069    0.358491
# 18      0.055556    0.379310    0.377358
# 19      0.052083    0.396552    0.396226
# 20      0.048611    0.413793    0.415094
#
# [21 rows x 26 columns]

# %%
traffic_dataset = original_dataset
# Preparing Traffic Dataset
# Remove date time. Remove unused columms
#0-2 = dt + lineName + stationName || 3-4 - statusN - statusS || 5-end - weather variables
cols_to_remove = [0, 1, 2] + list(range(5, traffic_dataset.shape[1]))

traffic_dataset = traffic_dataset.drop(traffic_dataset.columns[[cols_to_remove]], axis=1)
traffic_dataset = traffic_dataset.iloc[0:TIMESTEP]
traffic_dataset
# Out:
#    statusN  statusS
# 0      0.0      0.5
# 1      0.0      0.5
# 2      0.0      0.5
# 3      0.0      0.5
# 4      0.0      0.5
# 5      0.0      0.5
# 6      0.0      0.5
# 7      0.0      0.5
# 8      0.0      0.5
# 9      0.0      0.5

# %%
weather_dataset = original_dataset
# Remove date time. Remove unused columms
#0-2 = dt + lineName + stationName || 3-4 - statusN - statusS || 5-end - weather variables
cols_to_remove = [0, 1, 2] + [3, 4]

#Remove Redundant Variables
#Variables = tempC WindspeedKmph, cond, precipMM, humidity, visibility, pressure, cloudcover, dewPointC, windGustKmph, 
redundant_variables = [6, 7, 9, 16, 17, 19, 20, 21, 22, 24, 25]
cols_to_remove += redundant_variables
 
weather_dataset = weather_dataset.drop(weather_dataset.columns[[cols_to_remove]], axis=1)
weather_dataset = weather_dataset.iloc[0:TIMESTEP]
weather_dataset
# Out:
#     tempC  windspeedKmph      cond  precipMM  humidity  visibility  pressure  \
# 0  0.1500       0.102273  0.000000         0  0.818841           1  0.793103
# 1  0.1500       0.096591  0.000000         0  0.815217           1  0.793103
# 2  0.1500       0.090909  0.000000         0  0.811594           1  0.793103
# 3  0.1625       0.090909  0.000000         0  0.807971           1  0.793103
# 4  0.1750       0.090909  0.000000         0  0.804348           1  0.793103
# 5  0.1875       0.090909  0.000000         0  0.800725           1  0.793103
# 6  0.2000       0.090909  0.000000         0  0.797101           1  0.793103
# 7  0.2000       0.085227  0.223684         0  0.793478           1  0.793103
# 8  0.2000       0.079545  0.447368         0  0.789855           1  0.793103
# 9  0.2000       0.073864  0.671053         0  0.786232           1  0.793103
#
#    cloudcover  dewPointC  windGustKmph
# 0      0.1000   0.461538      0.104167
# 1      0.1000   0.461538      0.100694
# 2      0.1000   0.461538      0.097222
# 3      0.1025   0.461538      0.093750
# 4      0.1050   0.461538      0.090278
# 5      0.1075   0.461538      0.086806
# 6      0.1100   0.461538      0.083333
# 7      0.1100   0.461538      0.079861
# 8      0.1100   0.461538      0.076389
# 9      0.1100   0.461538      0.072917

# %%
y_test = original_dataset.iloc[TIMESTEP:(TIMESTEP*2)].statusS

# %%
pm1_Y_test = pm2_Y_test = y_test
pm1_Y_test
# Out:
# 10    0.5
# 11    0.5
# 12    0.5
# 13    0.5
# 14    0.5
# 15    0.5
# 16    0.5
# 17    1.0
# 18    1.0
# 19    1.0
# Name: statusS, dtype: float64

# %%
pm1_X_test = traffic_dataset
pm2_X_test = weather_dataset

# %%
# Save the model
pm1 = SupervisedDBNRegression.load('models/pm1_' + ROAD + '_' + YEAR + '.pkl')
pm2 = SupervisedDBNRegression.load('models/pm2_' + ROAD + '_' + YEAR + '.pkl')
fc = SupervisedDBNRegression.load('models/fc_' + ROAD + '_' + YEAR + '.pkl')

# %%
# Test PM1
pm1_Y_pred = pm1.predict(pm1_X_test)
print('Done.\nR-squared: %f\nMSE: %f' % (r2_score(pm1_Y_test, pm1_Y_pred), mean_squared_error(pm1_Y_test, pm1_Y_pred)))

# Test PM2
pm2_Y_pred = pm2.predict(pm2_X_test)
print('Done.\nR-squared: %f\nMSE: %f' % (r2_score(pm2_Y_test, pm2_Y_pred), mean_squared_error(pm2_Y_test, pm2_Y_pred)))
# Out:
# Done.
# R-squared: -0.430486
# MSE: 0.075101
# Done.
# R-squared: -0.489103
# MSE: 0.078178

# %%
# Compiling Results
pm1_temp = []
pm2_temp = []

for i in range(len(pm1_Y_pred)):
    pm1_temp.append(pm1_Y_pred[i][0])
    pm2_temp.append(pm2_Y_pred[i][0])
    
dpm1 = {'Predicted_PM1': pm1_temp, 'Predicted_PM2': pm2_temp, 'Actual': pm1_Y_test}
pm1_pm2_results = pd.DataFrame(data=dpm1)

pm1_pm2_results
# Out:
#     Actual  Predicted_PM1  Predicted_PM2
# 10     0.5       0.499665       0.467629
# 11     0.5       0.499665       0.467276
# 12     0.5       0.499665       0.466924
# 13     0.5       0.499665       0.474926
# 14     0.5       0.499665       0.482928
# 15     0.5       0.499665       0.490930
# 16     0.5       0.499665       0.498932
# 17     1.0       0.499665       0.494919
# 18     1.0       0.499665       0.490906
# 19     1.0       0.499665       0.486893

# %%
dfc = {'PM1-Output': pm1_pm2_results.Predicted_PM1, 'PM2-Output': pm1_pm2_results.Predicted_PM1}
fusion_dataset = pd.DataFrame(data=dfc)
fusion_dataset = np.array(fusion_dataset)
actual_dataset = pm1_pm2_results.Actual

# %%
fc_Y_test = y_test
fc_X_test = dfc

# %%
# Test FC
fc_Y_pred = fc.predict(pm1_X_test)
print('Done.\nR-squared: %f\nMSE: %f' % (r2_score(fc_Y_test, fc_Y_pred), mean_squared_error(fc_Y_test, fc_Y_pred)))
# Out:
# Done.
# R-squared: -8.378168
# MSE: 0.492354

# %%
temp = []
for i in range(len(fc_Y_pred)):
    temp.append(fc_Y_pred[i][0])
d = {'Predicted': temp, 'Actual': fc_Y_test}
fc_results = pd.DataFrame(data=d)
fc_results
# Out:
#     Actual  Predicted
# 10     0.5  -0.013215
# 11     0.5  -0.013215
# 12     0.5  -0.013215
# 13     0.5  -0.013215
# 14     0.5  -0.013215
# 15     0.5  -0.013215
# 16     0.5  -0.013215
# 17     1.0  -0.013215
# 18     1.0  -0.013215
# 19     1.0  -0.013215
