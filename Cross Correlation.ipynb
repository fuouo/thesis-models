# %%
import numpy as np
import pandas as pd

np.random.seed(1337)  # for reproducibility
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.regression import r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from dbn.tensorflow import SupervisedDBNRegression

# %% [markdown]
# ## Loading Datasets

# %%
ROAD = "Taft Ave."
YEAR = "2015"
EXT = ".csv"

# %%
TRAFFIC_WINDOWSIZE = 1
TRAFFIC_FILENAME = "eng_win" + str(TRAFFIC_WINDOWSIZE) + "_mmda_" + ROAD + "_" + YEAR
traffic_raw_data = pd.read_csv("data/mmda/" + TRAFFIC_FILENAME + EXT, skipinitialspace=True)
traffic_raw_data = traffic_raw_data.fillna(0)
#print("Start : " + str(original_dataset.columns[0:original_dataset.shape[1]][5]))
#print("End : " + str(original_dataset.columns[0:original_dataset.shape[1]][traffic_dataset.shape[1]-1]))

traffic_dataset = traffic_raw_data

# Remove date time. Remove unused columms
#0-2 = dt + lineName + stationName || 3-4 - statusN - statusS || 5-14 - original weather variables
#15-46 - engineered traffic
engineered = list(range(5, traffic_dataset.shape[1]))
cols_to_remove = [0, 1, 2] + engineered

traffic_dataset.drop(traffic_raw_data.columns[[cols_to_remove]], axis=1, inplace=True)
traffic_dataset.head()
# Out:
#    statusN  statusS
# 0      0.5      0.5
# 1      0.5      0.5
# 2      0.5      0.5
# 3      0.5      0.5
# 4      0.5      0.5

# %% [markdown]
# #### Weather Dataset

# %%
WEATHER_WINDOWSIZE = 2
WEATHER_FILENAME = "eng_win" + str(WEATHER_WINDOWSIZE) + "_wwo_" + ROAD + "_" + YEAR
weather_raw_data = pd.read_csv("data/wwo/" + WEATHER_FILENAME + EXT, skipinitialspace=True)
weather_raw_data = weather_raw_data.fillna(0)

weather_dataset = weather_raw_data

# Remove date time. Remove unused columms
#0-2 = dt + lineName + stationName || 3-12 - original weather variables
#12-beyond - engineered
# if windowsize = 1, 4 engineered features per original features
# We have 10 weather variables

temp = list(range(13, 17))
windspeedkmph = list(range(17, 21))
cond = list(range(21, 25))
precip = list(range(25, 29))
humid = list(range(29, 33))
visibility = list(range(33, 37))
pressure = list(range(37, 41))
cloudcover = list(range(41, 45))
dewpoint = list(range(45, 49))
windgustkmph = list(range(49, weather_dataset.shape[1]))

cols_to_remove = [0, 1, 2] 
#cols_to_remove += temp + windspeedkmph + cond + precip + humid + visibility + pressure + cloudcover + dewpoint + windgustkmph

weather_dataset = weather_dataset.drop(weather_dataset.columns[[cols_to_remove]], axis=1)
weather_dataset.head()
# Out:
#     tempC  windspeedKmph      cond  precipMM  humidity  visibility  pressure  \
# 0  0.2000       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 1  0.1875       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 2  0.1750       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 3  0.1625       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 4  0.1500       0.295455  0.631579       0.0   0.84058         1.0  0.758621
#
#    cloudcover  dewPointC  windGustKmph               ...                 \
# 0       0.330   0.538462      0.236111               ...
# 1       0.325   0.538462      0.239583               ...
# 2       0.320   0.538462      0.243056               ...
# 3       0.315   0.538462      0.246528               ...
# 4       0.310   0.538462      0.250000               ...
#
#    dewPointC_Rmean (window = 2)  dewPointC_Rmin  (window = 2)  \
# 0                      0.000000                      0.000000
# 1                      0.269231                      0.000000
# 2                      0.538462                      0.538462
# 3                      0.538462                      0.538462
# 4                      0.538462                      0.538462
#
#    dewPointC_Rmax  (window = 2)  windGustKmph_Emean  windGustKmph_Emin  \
# 0                      0.000000            0.236111           0.236111
# 1                      0.538462            0.237847           0.236111
# 2                      1.076923            0.239583           0.236111
# 3                      1.076923            0.241319           0.236111
# 4                      1.076923            0.243056           0.236111
#
#    windGustKmph_Emax  windGustKmph_Esum  windGustKmph_Rmean (window = 2)  \
# 0           0.236111           0.236111                         0.000000
# 1           0.239583           0.475694                         0.118056
# 2           0.243056           0.718750                         0.237847
# 3           0.246528           0.965278                         0.241319
# 4           0.250000           1.215278                         0.244792
#
#    windGustKmph_Rmin  (window = 2)  windGustKmph_Rmax  (window = 2)
# 0                         0.000000                         0.000000
# 1                         0.000000                         0.236111
# 2                         0.236111                         0.475694
# 3                         0.239583                         0.482639
# 4                         0.243056                         0.489583
#
# [5 rows x 80 columns]

# %%
weather_dataset['statusS'] = traffic_dataset.statusS
weather_dataset['statusN'] = traffic_dataset.statusN
weather_dataset.head()
# Out:
#     tempC  windspeedKmph      cond  precipMM  humidity  visibility  pressure  \
# 0  0.2000       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 1  0.1875       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 2  0.1750       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 3  0.1625       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 4  0.1500       0.295455  0.631579       0.0   0.84058         1.0  0.758621
#
#    cloudcover  dewPointC  windGustKmph   ...     dewPointC_Rmax  (window = 2)  \
# 0       0.330   0.538462      0.236111   ...                         0.000000
# 1       0.325   0.538462      0.239583   ...                         0.538462
# 2       0.320   0.538462      0.243056   ...                         1.076923
# 3       0.315   0.538462      0.246528   ...                         1.076923
# 4       0.310   0.538462      0.250000   ...                         1.076923
#
#    windGustKmph_Emean  windGustKmph_Emin  windGustKmph_Emax  \
# 0            0.236111           0.236111           0.236111
# 1            0.237847           0.236111           0.239583
# 2            0.239583           0.236111           0.243056
# 3            0.241319           0.236111           0.246528
# 4            0.243056           0.236111           0.250000
#
#    windGustKmph_Esum  windGustKmph_Rmean (window = 2)  \
# 0           0.236111                         0.000000
# 1           0.475694                         0.118056
# 2           0.718750                         0.237847
# 3           0.965278                         0.241319
# 4           1.215278                         0.244792
#
#    windGustKmph_Rmin  (window = 2)  windGustKmph_Rmax  (window = 2)  statusS  \
# 0                         0.000000                         0.000000      0.5
# 1                         0.000000                         0.236111      0.5
# 2                         0.236111                         0.475694      0.5
# 3                         0.239583                         0.482639      0.5
# 4                         0.243056                         0.489583      0.5
#
#    statusN
# 0      0.5
# 1      0.5
# 2      0.5
# 3      0.5
# 4      0.5
#
# [5 rows x 82 columns]

# %% [markdown]
# #### Flood Dataset

# %%
FLOOD_WINDOWSIZE = 1
FLOOD_FILENAME = "interpolated_flood_pagasa" + "_" + YEAR
flood_raw_data = pd.read_csv("data/flood/" + FLOOD_FILENAME + EXT, skipinitialspace=True)
flood_raw_data = flood_raw_data.fillna(0)

flood_dataset = flood_raw_data
flood_dataset = flood_dataset.drop(flood_dataset.columns[0], axis=1)

weather_dataset['flood_height'] = flood_dataset
weather_dataset.head()
# Out:
#     tempC  windspeedKmph      cond  precipMM  humidity  visibility  pressure  \
# 0  0.2000       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 1  0.1875       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 2  0.1750       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 3  0.1625       0.295455  0.631579       0.0   0.84058         1.0  0.758621
# 4  0.1500       0.295455  0.631579       0.0   0.84058         1.0  0.758621
#
#    cloudcover  dewPointC  windGustKmph      ...       windGustKmph_Emean  \
# 0       0.330   0.538462      0.236111      ...                 0.236111
# 1       0.325   0.538462      0.239583      ...                 0.237847
# 2       0.320   0.538462      0.243056      ...                 0.239583
# 3       0.315   0.538462      0.246528      ...                 0.241319
# 4       0.310   0.538462      0.250000      ...                 0.243056
#
#    windGustKmph_Emin  windGustKmph_Emax  windGustKmph_Esum  \
# 0           0.236111           0.236111           0.236111
# 1           0.236111           0.239583           0.475694
# 2           0.236111           0.243056           0.718750
# 3           0.236111           0.246528           0.965278
# 4           0.236111           0.250000           1.215278
#
#    windGustKmph_Rmean (window = 2)  windGustKmph_Rmin  (window = 2)  \
# 0                         0.000000                         0.000000
# 1                         0.118056                         0.000000
# 2                         0.237847                         0.236111
# 3                         0.241319                         0.239583
# 4                         0.244792                         0.243056
#
#    windGustKmph_Rmax  (window = 2)  statusS  statusN  flood_height
# 0                         0.000000      0.5      0.5      0.814856
# 1                         0.236111      0.5      0.5      0.814856
# 2                         0.475694      0.5      0.5      0.814856
# 3                         0.482639      0.5      0.5      0.814856
# 4                         0.489583      0.5      0.5      0.814856
#
# [5 rows x 83 columns]

# %% [markdown]
# ## Correlate

# %%
weather_dataset.corr()
# Out:
#                                      tempC  windspeedKmph      cond  precipMM  \
# tempC                             1.000000      -0.007605  0.481600 -0.056429
# windspeedKmph                    -0.007605       1.000000  0.043842  0.394904
# cond                              0.481600       0.043842  1.000000  0.030830
# precipMM                         -0.056429       0.394904  0.030830  1.000000
# humidity                         -0.838525      -0.146529 -0.447379  0.252669
# visibility                        0.079958      -0.269017 -0.090585 -0.806017
# pressure                         -0.238549      -0.138577 -0.136204 -0.484652
# cloudcover                       -0.160244       0.213816  0.045433  0.500202
# dewPointC                         0.284565      -0.239925  0.109487  0.315964
# windGustKmph                     -0.142279       0.935749 -0.014572  0.596349
# tempC_Emean                       0.253818      -0.175949  0.082507  0.209983
# tempC_Emin                       -0.147754       0.132105  0.009660 -0.038690
# tempC_Emax                        0.303741      -0.180677  0.056548  0.169826
# tempC_Esum                        0.068928      -0.073427  0.031997  0.162282
# tempC_Rmean (window = 2)          0.995451       0.010085  0.454713 -0.047251
# tempC_Rmin  (window = 2)          0.994781       0.013067  0.452733 -0.045314
# tempC_Rmax  (window = 2)          0.995451       0.010085  0.454713 -0.047251
# windspeedKmph_Emean              -0.204895       0.169726 -0.048544 -0.169517
# windspeedKmph_Emin               -0.260847       0.195150 -0.042366 -0.145488
# windspeedKmph_Emax               -0.103951       0.149293 -0.062432  0.022501
# windspeedKmph_Esum                0.092121      -0.075561  0.025390  0.154223
# windspeedKmph_Rmean (window = 2) -0.027698       0.996771  0.021431  0.392797
# windspeedKmph_Rmin  (window = 2) -0.029082       0.996431  0.021225  0.392328
# windspeedKmph_Rmax  (window = 2) -0.027698       0.996771  0.021431  0.392797
# cond_Emean                       -0.173460       0.024090  0.046693  0.137546
# cond_Emin                        -0.020429       0.012522  0.001883 -0.004631
# cond_Emax                         0.002665      -0.076907  0.058523  0.233653
# cond_Esum                         0.059103      -0.065680  0.025332  0.154461
# cond_Rmean (window = 2)           0.507152       0.066233  0.967436  0.032288
# cond_Rmin  (window = 2)           0.509685       0.067346  0.963998  0.033809
# ...                                    ...            ...       ...       ...
# pressure_Emin                     0.058453      -0.092780  0.032728 -0.114871
# pressure_Emax                     0.263085      -0.147307  0.008475  0.080729
# pressure_Esum                     0.091383      -0.076660  0.027344  0.153574
# pressure_Rmean (window = 2)      -0.229492      -0.138193 -0.129212 -0.484599
# pressure_Rmin  (window = 2)      -0.230489      -0.139955 -0.129677 -0.486126
# pressure_Rmax  (window = 2)      -0.229492      -0.138193 -0.129212 -0.484599
# cloudcover_Emean                 -0.394475       0.145823 -0.042788 -0.039800
# cloudcover_Emin                  -0.133136       0.109563  0.008360 -0.037238
# cloudcover_Emax                   0.145926      -0.109715  0.030525  0.209518
# cloudcover_Esum                   0.028896      -0.053341  0.016283  0.144579
# cloudcover_Rmean (window = 2)    -0.159249       0.222891  0.048744  0.498308
# cloudcover_Rmin  (window = 2)    -0.160412       0.223315  0.047867  0.498697
# cloudcover_Rmax  (window = 2)    -0.159249       0.222891  0.048744  0.498308
# dewPointC_Emean                  -0.021369      -0.057396  0.052281  0.177908
# dewPointC_Emin                   -0.317443       0.171739 -0.034635 -0.116842
# dewPointC_Emax                    0.037572      -0.137830  0.022562  0.115772
# dewPointC_Esum                    0.040758      -0.056599  0.021580  0.148629
# dewPointC_Rmean (window = 2)      0.289442      -0.241213  0.111303  0.316607
# dewPointC_Rmin  (window = 2)      0.287711      -0.241806  0.110233  0.315426
# dewPointC_Rmax  (window = 2)      0.289442      -0.241213  0.111303  0.316607
# windGustKmph_Emean               -0.264365       0.192126 -0.055253 -0.160470
# windGustKmph_Emin                -0.215951       0.181496 -0.036696 -0.143241
# windGustKmph_Emax                -0.070997       0.061686 -0.019667  0.123256
# windGustKmph_Esum                 0.075957      -0.069039  0.022100  0.150820
# windGustKmph_Rmean (window = 2)  -0.160807       0.930446 -0.029200  0.592356
# windGustKmph_Rmin  (window = 2)  -0.162487       0.930077 -0.030078  0.589274
# windGustKmph_Rmax  (window = 2)  -0.160807       0.930446 -0.029200  0.592356
# statusS                           0.323177       0.101277  0.143669  0.017662
# statusN                           0.095285       0.051301  0.047232  0.021161
# flood_height                     -0.072133       0.209137 -0.099054 -0.175910
#
#                                   humidity  visibility  pressure  cloudcover  \
# tempC                            -0.838525    0.079958 -0.238549   -0.160244
# windspeedKmph                    -0.146529   -0.269017 -0.138577    0.213816
# cond                             -0.447379   -0.090585 -0.136204    0.045433
# precipMM                          0.252669   -0.806017 -0.484652    0.500202
# humidity                          1.000000   -0.275902 -0.105513    0.295515
# visibility                       -0.275902    1.000000  0.436105   -0.496318
# pressure                         -0.105513    0.436105  1.000000   -0.407769
# cloudcover                        0.295515   -0.496318 -0.407769    1.000000
# dewPointC                         0.247395   -0.311956 -0.586977    0.231943
# windGustKmph                      0.068615   -0.461063 -0.274911    0.371129
# tempC_Emean                       0.135786   -0.173729 -0.491289    0.130078
# tempC_Emin                        0.110169   -0.006793  0.091227    0.061440
# tempC_Emax                        0.028208   -0.115735 -0.427537    0.049963
# tempC_Esum                        0.204464   -0.119132 -0.257160    0.099189
# tempC_Rmean (window = 2)         -0.832832    0.069521 -0.246914   -0.160854
# tempC_Rmin  (window = 2)         -0.831689    0.067306 -0.250103   -0.158466
# tempC_Rmax  (window = 2)         -0.832832    0.069521 -0.246914   -0.160854
# windspeedKmph_Emean              -0.082518    0.114932  0.362461   -0.061290
# windspeedKmph_Emin               -0.000493    0.093625  0.338577   -0.027201
# windspeedKmph_Emax                0.111021    0.035029  0.114905   -0.046362
# windspeedKmph_Esum                0.175608   -0.104783 -0.243379    0.076253
# windspeedKmph_Rmean (window = 2) -0.124180   -0.269480 -0.137048    0.203876
# windspeedKmph_Rmin  (window = 2) -0.122216   -0.270501 -0.138122    0.204457
# windspeedKmph_Rmax  (window = 2) -0.124180   -0.269480 -0.137048    0.203876
# cond_Emean                        0.337521   -0.161418 -0.136021    0.224332
# cond_Emin                         0.013314    0.005430  0.003267    0.002416
# cond_Emax                         0.281909   -0.218671 -0.335388    0.236653
# cond_Esum                         0.199833   -0.108611 -0.231769    0.087759
# cond_Rmean (window = 2)          -0.472778   -0.088066 -0.143933    0.043377
# cond_Rmin  (window = 2)          -0.474876   -0.090186 -0.143845    0.045445
# ...                                    ...         ...       ...         ...
# pressure_Emin                    -0.170441    0.051763  0.050358   -0.043264
# pressure_Emax                    -0.105421   -0.004132 -0.196037   -0.077603
# pressure_Esum                     0.177919   -0.104389 -0.248942    0.077055
# pressure_Rmean (window = 2)      -0.116158    0.436963  0.997420   -0.407714
# pressure_Rmin  (window = 2)      -0.114731    0.437203  0.996770   -0.407770
# pressure_Rmax  (window = 2)      -0.116158    0.436963  0.997420   -0.407714
# cloudcover_Emean                  0.224880   -0.018381  0.308925    0.090230
# cloudcover_Emin                   0.108944   -0.021775  0.076916    0.066669
# cloudcover_Emax                   0.127115   -0.150749 -0.328716    0.120396
# cloudcover_Esum                   0.207437   -0.098592 -0.187182    0.079779
# cloudcover_Rmean (window = 2)     0.293622   -0.495534 -0.406977    0.997278
# cloudcover_Rmin  (window = 2)     0.295369   -0.496708 -0.408354    0.997253
# cloudcover_Rmax  (window = 2)     0.293622   -0.495534 -0.406977    0.997278
# dewPointC_Emean                   0.303282   -0.176826 -0.280275    0.181099
# dewPointC_Emin                    0.084976    0.041142  0.315713    0.026675
# dewPointC_Emax                    0.162363   -0.093930 -0.163441    0.060229
# dewPointC_Esum                    0.206368   -0.104215 -0.210705    0.086187
# dewPointC_Rmean (window = 2)      0.242779   -0.312373 -0.585534    0.232147
# dewPointC_Rmin  (window = 2)      0.244116   -0.311480 -0.585248    0.232268
# dewPointC_Rmax  (window = 2)      0.242779   -0.312373 -0.585534    0.232147
# windGustKmph_Emean               -0.029596    0.106659  0.401113   -0.044864
# windGustKmph_Emin                -0.007321    0.086230  0.297579   -0.031906
# windGustKmph_Emax                 0.206154   -0.075762 -0.053581    0.066998
# windGustKmph_Esum                 0.182675   -0.101986 -0.225587    0.075477
# windGustKmph_Rmean (window = 2)   0.088696   -0.460159 -0.271498    0.364391
# windGustKmph_Rmin  (window = 2)   0.090029   -0.459345 -0.270848    0.363902
# windGustKmph_Rmax  (window = 2)   0.088696   -0.460159 -0.271498    0.364391
# statusS                          -0.304857   -0.033461 -0.006166   -0.057772
# statusN                          -0.085335   -0.019734  0.040651    0.006598
# flood_height                     -0.179746    0.184467  0.296318   -0.156995
#
#                                   dewPointC  windGustKmph      ...       \
# tempC                              0.284565     -0.142279      ...
# windspeedKmph                     -0.239925      0.935749      ...
# cond                               0.109487     -0.014572      ...
# precipMM                           0.315964      0.596349      ...
# humidity                           0.247395      0.068615      ...
# visibility                        -0.311956     -0.461063      ...
# pressure                          -0.586977     -0.274911      ...
# cloudcover                         0.231943      0.371129      ...
# dewPointC                          1.000000     -0.126956      ...
# windGustKmph                      -0.126956      1.000000      ...
# tempC_Emean                        0.711709     -0.078499      ...
# tempC_Emin                        -0.078007      0.097244      ...
# tempC_Emax                         0.601015     -0.101126      ...
# tempC_Esum                         0.521618     -0.000791      ...
# tempC_Rmean (window = 2)           0.279432     -0.124543      ...
# tempC_Rmin  (window = 2)           0.280081     -0.121128      ...
# tempC_Rmax  (window = 2)           0.279432     -0.124543      ...
# windspeedKmph_Emean               -0.538762      0.083515      ...
# windspeedKmph_Emin                -0.482638      0.116115      ...
# windspeedKmph_Emax                 0.051994      0.149168      ...
# windspeedKmph_Esum                 0.509024     -0.007076      ...
# windspeedKmph_Rmean (window = 2)  -0.238310      0.935962      ...
# windspeedKmph_Rmin  (window = 2)  -0.237605      0.936255      ...
# windspeedKmph_Rmax  (window = 2)  -0.238310      0.935962      ...
# cond_Emean                         0.323647      0.081225      ...
# cond_Emin                         -0.010527      0.010721      ...
# cond_Emax                          0.538272      0.025417      ...
# cond_Esum                          0.496501      0.003009      ...
# cond_Rmean (window = 2)            0.108887      0.000621      ...
# cond_Rmin  (window = 2)            0.108859      0.001917      ...
# ...                                     ...           ...      ...
# pressure_Emin                     -0.239194     -0.131714      ...
# pressure_Emax                      0.280951     -0.107866      ...
# pressure_Esum                      0.512656     -0.008270      ...
# pressure_Rmean (window = 2)       -0.588245     -0.276033      ...
# pressure_Rmin  (window = 2)       -0.587383     -0.277512      ...
# pressure_Rmax  (window = 2)       -0.588245     -0.276033      ...
# cloudcover_Emean                  -0.280411      0.128246      ...
# cloudcover_Emin                   -0.055620      0.080109      ...
# cloudcover_Emax                    0.512302     -0.019880      ...
# cloudcover_Esum                    0.457688      0.010848      ...
# cloudcover_Rmean (window = 2)      0.231965      0.376479      ...
# cloudcover_Rmin  (window = 2)      0.232573      0.377334      ...
# cloudcover_Rmax  (window = 2)      0.231965      0.376479      ...
# dewPointC_Emean                    0.537526      0.024103      ...
# dewPointC_Emin                    -0.418860      0.114526      ...
# dewPointC_Emax                     0.386912     -0.073051      ...
# dewPointC_Esum                     0.476627      0.009536      ...
# dewPointC_Rmean (window = 2)       0.996295     -0.127977      ...
# dewPointC_Rmin  (window = 2)       0.995832     -0.128392      ...
# dewPointC_Rmax  (window = 2)       0.996295     -0.127977      ...
# windGustKmph_Emean                -0.543214      0.108525      ...
# windGustKmph_Emin                 -0.417642      0.102795      ...
# windGustKmph_Emax                  0.279680      0.108778      ...
# windGustKmph_Esum                  0.493823     -0.002112      ...
# windGustKmph_Rmean (window = 2)   -0.125503      0.997019      ...
# windGustKmph_Rmin  (window = 2)   -0.126323      0.996730      ...
# windGustKmph_Rmax  (window = 2)   -0.125503      0.997019      ...
# statusS                            0.018936      0.039567      ...
# statusN                            0.017479      0.028615      ...
# flood_height                      -0.451438      0.126425      ...
#
#                                   windGustKmph_Emean  windGustKmph_Emin  \
# tempC                                      -0.264365          -0.215951
# windspeedKmph                               0.192126           0.181496
# cond                                       -0.055253          -0.036696
# precipMM                                   -0.160470          -0.143241
# humidity                                   -0.029596          -0.007321
# visibility                                  0.106659           0.086230
# pressure                                    0.401113           0.297579
# cloudcover                                 -0.044864          -0.031906
# dewPointC                                  -0.543214          -0.417642
# windGustKmph                                0.108525           0.102795
# tempC_Emean                                -0.882704          -0.765075
# tempC_Emin                                  0.661106           0.791748
# tempC_Emax                                 -0.936935          -0.855692
# tempC_Esum                                 -0.735938          -0.638731
# tempC_Rmean (window = 2)                   -0.264799          -0.216542
# tempC_Rmin  (window = 2)                   -0.266382          -0.217847
# tempC_Rmax  (window = 2)                   -0.264799          -0.216542
# windspeedKmph_Emean                         0.980582           0.924609
# windspeedKmph_Emin                          0.961726           0.976612
# windspeedKmph_Emax                         -0.385705          -0.357933
# windspeedKmph_Esum                         -0.760164          -0.666906
# windspeedKmph_Rmean (window = 2)            0.192859           0.181166
# windspeedKmph_Rmin  (window = 2)            0.193703           0.182034
# windspeedKmph_Rmax  (window = 2)            0.192859           0.181166
# cond_Emean                                 -0.106370          -0.086123
# cond_Emin                                   0.049922           0.110127
# cond_Emax                                  -0.650867          -0.617681
# cond_Esum                                  -0.729951          -0.637204
# cond_Rmean (window = 2)                    -0.055648          -0.037451
# cond_Rmin  (window = 2)                    -0.055236          -0.037404
# ...                                              ...                ...
# pressure_Emin                               0.552180           0.511781
# pressure_Emax                              -0.767680          -0.795912
# pressure_Esum                              -0.762386          -0.664563
# pressure_Rmean (window = 2)                 0.399950           0.295301
# pressure_Rmin  (window = 2)                 0.399577           0.294607
# pressure_Rmax  (window = 2)                 0.399950           0.295301
# cloudcover_Emean                            0.537492           0.455955
# cloudcover_Emin                             0.672318           0.785589
# cloudcover_Emax                            -0.865784          -0.843268
# cloudcover_Esum                            -0.693755          -0.611568
# cloudcover_Rmean (window = 2)              -0.044987          -0.032401
# cloudcover_Rmin  (window = 2)              -0.044502          -0.031997
# cloudcover_Rmax  (window = 2)              -0.044987          -0.032401
# dewPointC_Emean                            -0.530743          -0.428048
# dewPointC_Emin                              0.858231           0.819740
# dewPointC_Emax                             -0.699860          -0.732497
# dewPointC_Esum                             -0.704475          -0.614461
# dewPointC_Rmean (window = 2)               -0.544009          -0.418957
# dewPointC_Rmin  (window = 2)               -0.545295          -0.420565
# dewPointC_Rmax  (window = 2)               -0.544009          -0.418957
# windGustKmph_Emean                          1.000000           0.945166
# windGustKmph_Emin                           0.945166           1.000000
# windGustKmph_Emax                          -0.513413          -0.470748
# windGustKmph_Esum                          -0.743049          -0.653013
# windGustKmph_Rmean (window = 2)             0.109211           0.102498
# windGustKmph_Rmin  (window = 2)             0.110661           0.103871
# windGustKmph_Rmax  (window = 2)             0.109211           0.102498
# statusS                                     0.046307           0.025124
# statusN                                    -0.001745           0.017669
# flood_height                                0.285574           0.266504
#
#                                   windGustKmph_Emax  windGustKmph_Esum  \
# tempC                                     -0.070997           0.075957
# windspeedKmph                              0.061686          -0.069039
# cond                                      -0.019667           0.022100
# precipMM                                   0.123256           0.150820
# humidity                                   0.206154           0.182675
# visibility                                -0.075762          -0.101986
# pressure                                  -0.053581          -0.225587
# cloudcover                                 0.066998           0.075477
# dewPointC                                  0.279680           0.493823
# windGustKmph                               0.108778          -0.002112
# tempC_Emean                                0.649144           0.868464
# tempC_Emin                                -0.150057          -0.264377
# tempC_Emax                                 0.539928           0.779321
# tempC_Esum                                 0.911242           0.995700
# tempC_Rmean (window = 2)                  -0.070908           0.076236
# tempC_Rmin  (window = 2)                  -0.068969           0.078333
# tempC_Rmax  (window = 2)                  -0.070908           0.076236
# windspeedKmph_Emean                       -0.645233          -0.831944
# windspeedKmph_Emin                        -0.470507          -0.679553
# windspeedKmph_Emax                         0.916618           0.782792
# windspeedKmph_Esum                         0.903725           0.999139
# windspeedKmph_Rmean (window = 2)           0.062238          -0.068889
# windspeedKmph_Rmin  (window = 2)           0.061631          -0.069776
# windspeedKmph_Rmax  (window = 2)           0.062238          -0.068889
# cond_Emean                                 0.638668           0.547847
# cond_Emin                                 -0.023401          -0.026127
# cond_Emax                                  0.787137           0.846150
# cond_Esum                                  0.921637           0.996922
# cond_Rmean (window = 2)                   -0.019724           0.022286
# cond_Rmin  (window = 2)                   -0.019939           0.021760
# ...                                             ...                ...
# pressure_Emin                             -0.979362          -0.907706
# pressure_Emax                              0.273991           0.470139
# pressure_Esum                              0.900981           0.998657
# pressure_Rmean (window = 2)               -0.053671          -0.225136
# pressure_Rmin  (window = 2)               -0.054368          -0.225713
# pressure_Rmax  (window = 2)               -0.053671          -0.225136
# cloudcover_Emean                           0.168467          -0.123179
# cloudcover_Emin                           -0.144535          -0.254542
# cloudcover_Emax                            0.728369           0.856848
# cloudcover_Esum                            0.943084           0.991209
# cloudcover_Rmean (window = 2)              0.067393           0.075607
# cloudcover_Rmin  (window = 2)              0.066235           0.074428
# cloudcover_Rmax  (window = 2)              0.067393           0.075607
# dewPointC_Emean                            0.857000           0.880362
# dewPointC_Emin                            -0.381555          -0.615120
# dewPointC_Emax                             0.788457           0.810490
# dewPointC_Esum                             0.932930           0.994204
# dewPointC_Rmean (window = 2)               0.280105           0.494239
# dewPointC_Rmin  (window = 2)               0.280313           0.494613
# dewPointC_Rmax  (window = 2)               0.280105           0.494239
# windGustKmph_Emean                        -0.513413          -0.743049
# windGustKmph_Emin                         -0.470748          -0.653013
# windGustKmph_Emax                          1.000000           0.917303
# windGustKmph_Esum                          0.917303           1.000000
# windGustKmph_Rmean (window = 2)            0.109431          -0.001968
# windGustKmph_Rmin  (window = 2)            0.108409          -0.003721
# windGustKmph_Rmax  (window = 2)            0.109431          -0.001968
# statusS                                   -0.207534          -0.175229
# statusN                                    0.137483           0.113430
# flood_height                              -0.224574          -0.330286
#
#                                   windGustKmph_Rmean (window = 2)  \
# tempC                                                   -0.160807
# windspeedKmph                                            0.930446
# cond                                                    -0.029200
# precipMM                                                 0.592356
# humidity                                                 0.088696
# visibility                                              -0.460159
# pressure                                                -0.271498
# cloudcover                                               0.364391
# dewPointC                                               -0.125503
# windGustKmph                                             0.997019
# tempC_Emean                                             -0.078353
# tempC_Emin                                               0.095738
# tempC_Emax                                              -0.100858
# tempC_Esum                                              -0.000769
# tempC_Rmean (window = 2)                                -0.142287
# tempC_Rmin  (window = 2)                                -0.138942
# tempC_Rmax  (window = 2)                                -0.142287
# windspeedKmph_Emean                                      0.084109
# windspeedKmph_Emin                                       0.115775
# windspeedKmph_Emax                                       0.150023
# windspeedKmph_Esum                                      -0.006942
# windspeedKmph_Rmean (window = 2)                         0.935836
# windspeedKmph_Rmin  (window = 2)                         0.936210
# windspeedKmph_Rmax  (window = 2)                         0.935836
# cond_Emean                                               0.080960
# cond_Emin                                                0.003218
# cond_Emax                                                0.026170
# cond_Esum                                                0.003041
# cond_Rmean (window = 2)                                 -0.014495
# cond_Rmin  (window = 2)                                 -0.013202
# ...                                                           ...
# pressure_Emin                                           -0.131896
# pressure_Emax                                           -0.106935
# pressure_Esum                                           -0.008237
# pressure_Rmean (window = 2)                             -0.274366
# pressure_Rmin  (window = 2)                             -0.275744
# pressure_Rmax  (window = 2)                             -0.274366
# cloudcover_Emean                                         0.128281
# cloudcover_Emin                                          0.079329
# cloudcover_Emax                                         -0.019373
# cloudcover_Esum                                          0.010922
# cloudcover_Rmean (window = 2)                            0.371225
# cloudcover_Rmin  (window = 2)                            0.372181
# cloudcover_Rmax  (window = 2)                            0.371225
# dewPointC_Emean                                          0.024001
# dewPointC_Emin                                           0.113948
# dewPointC_Emax                                          -0.072101
# dewPointC_Esum                                           0.009559
# dewPointC_Rmean (window = 2)                            -0.126722
# dewPointC_Rmin  (window = 2)                            -0.127058
# dewPointC_Rmax  (window = 2)                            -0.126722
# windGustKmph_Emean                                       0.109211
# windGustKmph_Emin                                        0.102498
# windGustKmph_Emax                                        0.109431
# windGustKmph_Esum                                       -0.001968
# windGustKmph_Rmean (window = 2)                          1.000000
# windGustKmph_Rmin  (window = 2)                          0.999747
# windGustKmph_Rmax  (window = 2)                          1.000000
# statusS                                                  0.039169
# statusN                                                  0.027959
# flood_height                                             0.126766
#
#                                   windGustKmph_Rmin  (window = 2)  \
# tempC                                                   -0.162487
# windspeedKmph                                            0.930077
# cond                                                    -0.030078
# precipMM                                                 0.589274
# humidity                                                 0.090029
# visibility                                              -0.459345
# pressure                                                -0.270848
# cloudcover                                               0.363902
# dewPointC                                               -0.126323
# windGustKmph                                             0.996730
# tempC_Emean                                             -0.079624
# tempC_Emin                                               0.096308
# tempC_Emax                                              -0.102245
# tempC_Esum                                              -0.002379
# tempC_Rmean (window = 2)                                -0.143962
# tempC_Rmin  (window = 2)                                -0.140567
# tempC_Rmax  (window = 2)                                -0.143962
# windspeedKmph_Emean                                      0.085621
# windspeedKmph_Emin                                       0.117183
# windspeedKmph_Emax                                       0.149099
# windspeedKmph_Esum                                      -0.008715
# windspeedKmph_Rmean (window = 2)                         0.935563
# windspeedKmph_Rmin  (window = 2)                         0.936300
# windspeedKmph_Rmax  (window = 2)                         0.935563
# cond_Emean                                               0.080830
# cond_Emin                                                0.000938
# cond_Emax                                                0.025204
# cond_Esum                                                0.001408
# cond_Rmean (window = 2)                                 -0.015467
# cond_Rmin  (window = 2)                                 -0.014101
# ...                                                           ...
# pressure_Emin                                           -0.130640
# pressure_Emax                                           -0.108120
# pressure_Esum                                           -0.009969
# pressure_Rmean (window = 2)                             -0.273615
# pressure_Rmin  (window = 2)                             -0.274699
# pressure_Rmax  (window = 2)                             -0.273615
# cloudcover_Emean                                         0.129158
# cloudcover_Emin                                          0.080099
# cloudcover_Emax                                         -0.020623
# cloudcover_Esum                                          0.009312
# cloudcover_Rmean (window = 2)                            0.370721
# cloudcover_Rmin  (window = 2)                            0.371871
# cloudcover_Rmax  (window = 2)                            0.370721
# dewPointC_Emean                                          0.023120
# dewPointC_Emin                                           0.115390
# dewPointC_Emax                                          -0.073196
# dewPointC_Esum                                           0.007941
# dewPointC_Rmean (window = 2)                            -0.127508
# dewPointC_Rmin  (window = 2)                            -0.127742
# dewPointC_Rmax  (window = 2)                            -0.127508
# windGustKmph_Emean                                       0.110661
# windGustKmph_Emin                                        0.103871
# windGustKmph_Emax                                        0.108409
# windGustKmph_Esum                                       -0.003721
# windGustKmph_Rmean (window = 2)                          0.999747
# windGustKmph_Rmin  (window = 2)                          1.000000
# windGustKmph_Rmax  (window = 2)                          0.999747
# statusS                                                  0.038250
# statusN                                                  0.027568
# flood_height                                             0.127494
#
#                                   windGustKmph_Rmax  (window = 2)   statusS  \
# tempC                                                   -0.160807  0.323177
# windspeedKmph                                            0.930446  0.101277
# cond                                                    -0.029200  0.143669
# precipMM                                                 0.592356  0.017662
# humidity                                                 0.088696 -0.304857
# visibility                                              -0.460159 -0.033461
# pressure                                                -0.271498 -0.006166
# cloudcover                                               0.364391 -0.057772
# dewPointC                                               -0.125503  0.018936
# windGustKmph                                             0.997019  0.039567
# tempC_Emean                                             -0.078353 -0.089355
# tempC_Emin                                               0.095738 -0.015874
# tempC_Emax                                              -0.100858 -0.056618
# tempC_Esum                                              -0.000769 -0.177293
# tempC_Rmean (window = 2)                                -0.142287  0.338746
# tempC_Rmin  (window = 2)                                -0.138942  0.335775
# tempC_Rmax  (window = 2)                                -0.142287  0.338746
# windspeedKmph_Emean                                      0.084109  0.082782
# windspeedKmph_Emin                                       0.115775  0.023637
# windspeedKmph_Emax                                       0.150023 -0.200450
# windspeedKmph_Esum                                      -0.006942 -0.170175
# windspeedKmph_Rmean (window = 2)                         0.935836  0.104467
# windspeedKmph_Rmin  (window = 2)                         0.936210  0.102890
# windspeedKmph_Rmax  (window = 2)                         0.935836  0.104467
# cond_Emean                                               0.080960 -0.149796
# cond_Emin                                                0.003218 -0.005830
# cond_Emax                                                0.026170 -0.145505
# cond_Esum                                                0.003041 -0.180300
# cond_Rmean (window = 2)                                 -0.014495  0.170491
# cond_Rmin  (window = 2)                                 -0.013202  0.171923
# ...                                                           ...       ...
# pressure_Emin                                           -0.131896  0.202575
# pressure_Emax                                           -0.106935  0.017479
# pressure_Esum                                           -0.008237 -0.171450
# pressure_Rmean (window = 2)                             -0.274366 -0.010694
# pressure_Rmin  (window = 2)                             -0.275744 -0.011185
# pressure_Rmax  (window = 2)                             -0.274366 -0.010694
# cloudcover_Emean                                         0.128281 -0.093024
# cloudcover_Emin                                          0.079329 -0.023693
# cloudcover_Emax                                         -0.019373 -0.106599
# cloudcover_Esum                                          0.010922 -0.187919
# cloudcover_Rmean (window = 2)                            0.371225 -0.054274
# cloudcover_Rmin  (window = 2)                            0.372181 -0.053281
# cloudcover_Rmax  (window = 2)                            0.371225 -0.054274
# dewPointC_Emean                                          0.024001 -0.184968
# dewPointC_Emin                                           0.113948  0.017363
# dewPointC_Emax                                          -0.072101 -0.132745
# dewPointC_Esum                                           0.009559 -0.186177
# dewPointC_Rmean (window = 2)                            -0.126722  0.022739
# dewPointC_Rmin  (window = 2)                            -0.127058  0.021745
# dewPointC_Rmax  (window = 2)                            -0.126722  0.022739
# windGustKmph_Emean                                       0.109211  0.046307
# windGustKmph_Emin                                        0.102498  0.025124
# windGustKmph_Emax                                        0.109431 -0.207534
# windGustKmph_Esum                                       -0.001968 -0.175229
# windGustKmph_Rmean (window = 2)                          1.000000  0.039169
# windGustKmph_Rmin  (window = 2)                          0.999747  0.038250
# windGustKmph_Rmax  (window = 2)                          1.000000  0.039169
# statusS                                                  0.039169  1.000000
# statusN                                                  0.027959  0.243458
# flood_height                                             0.126766  0.035639
#
#                                    statusN  flood_height
# tempC                             0.095285     -0.072133
# windspeedKmph                     0.051301      0.209137
# cond                              0.047232     -0.099054
# precipMM                          0.021161     -0.175910
# humidity                         -0.085335     -0.179746
# visibility                       -0.019734      0.184467
# pressure                          0.040651      0.296318
# cloudcover                        0.006598     -0.156995
# dewPointC                         0.017479     -0.451438
# windGustKmph                      0.028615      0.126425
# tempC_Emean                       0.016565     -0.392674
# tempC_Emin                        0.046073      0.076529
# tempC_Emax                       -0.025638     -0.303156
# tempC_Esum                        0.119267     -0.351641
# tempC_Rmean (window = 2)          0.104422     -0.072023
# tempC_Rmin  (window = 2)          0.103520     -0.072899
# tempC_Rmax  (window = 2)          0.104422     -0.072023
# windspeedKmph_Emean              -0.043523      0.346334
# windspeedKmph_Emin                0.034102      0.264053
# windspeedKmph_Emax                0.131763      0.078859
# windspeedKmph_Esum                0.105937     -0.326230
# windspeedKmph_Rmean (window = 2)  0.052825      0.209634
# windspeedKmph_Rmin  (window = 2)  0.052674      0.209311
# windspeedKmph_Rmax  (window = 2)  0.052825      0.209634
# cond_Emean                        0.148293     -0.379182
# cond_Emin                         0.018060      0.007337
# cond_Emax                         0.094192     -0.465381
# cond_Esum                         0.124326     -0.343091
# cond_Rmean (window = 2)           0.063640     -0.099711
# cond_Rmin  (window = 2)           0.065129     -0.099157
# ...                                    ...           ...
# pressure_Emin                    -0.122872      0.113520
# pressure_Emax                    -0.058524     -0.145296
# pressure_Esum                     0.110015     -0.324081
# pressure_Rmean (window = 2)       0.038460      0.295964
# pressure_Rmin  (window = 2)       0.037589      0.295567
# pressure_Rmax  (window = 2)       0.038460      0.295964
# cloudcover_Emean                  0.151173     -0.090635
# cloudcover_Emin                   0.036531      0.073742
# cloudcover_Emax                   0.037531     -0.422612
# cloudcover_Esum                   0.135754     -0.349398
# cloudcover_Rmean (window = 2)     0.007338     -0.156849
# cloudcover_Rmin  (window = 2)     0.007336     -0.156742
# cloudcover_Rmax  (window = 2)     0.007338     -0.156849
# dewPointC_Emean                   0.137439     -0.418244
# dewPointC_Emin                    0.051134      0.205567
# dewPointC_Emax                    0.084752     -0.474424
# dewPointC_Esum                    0.131486     -0.335078
# dewPointC_Rmean (window = 2)      0.019213     -0.451645
# dewPointC_Rmin  (window = 2)      0.018057     -0.450842
# dewPointC_Rmax  (window = 2)      0.019213     -0.451645
# windGustKmph_Emean               -0.001745      0.285574
# windGustKmph_Emin                 0.017669      0.266504
# windGustKmph_Emax                 0.137483     -0.224574
# windGustKmph_Esum                 0.113430     -0.330286
# windGustKmph_Rmean (window = 2)   0.027959      0.126766
# windGustKmph_Rmin  (window = 2)   0.027568      0.127494
# windGustKmph_Rmax  (window = 2)   0.027959      0.126766
# statusS                           0.243458      0.035639
# statusN                           1.000000     -0.054974
# flood_height                     -0.054974      1.000000
#
# [83 rows x 83 columns]

# %%
weather_dataset.corr().to_csv("stats/cross-correlation2_" + YEAR + EXT, encoding='utf-8')
